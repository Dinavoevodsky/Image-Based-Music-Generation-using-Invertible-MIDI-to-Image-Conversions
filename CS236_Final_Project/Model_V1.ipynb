# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CS236/CS236\ Final\ Project
# !pip install torch===1.7.1+cu110 torchvision===0.8.2+cu110 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |███████████████████████         | 834.1 MB 1.6 MB/s eta 0:03:29tcmalloc: large alloc 1147494400 bytes == 0x558e9f380000 @  0x7f44bc2ed615 0x558e6592d4cc 0x558e65a0d47a 0x558e659302ed 0x558e65a21e1d 0x558e659a3e99 0x558e6599e9ee 0x558e65931bda 0x558e659a3d00 0x558e6599e9ee 0x558e65931bda 0x558e659a0737 0x558e65a22c66 0x558e6599fdaf 0x558e65a22c66 0x558e6599fdaf 0x558e65a22c66 0x558e6599fdaf 0x558e65932039 0x558e65975409 0x558e65930c52 0x558e659a3c25 0x558e6599e9ee 0x558e65931bda 0x558e659a0737 0x558e6599e9ee 0x558e65931bda 0x558e6599f915 0x558e65931afa 0x558e6599fc0d 0x558e6599e9ee
# ...

# %%
# !cd '/content/drive/MyDrive'

# %% [markdown]
# ### Checking Versions

# %%
# need Python 3.7.x
import sys
print(sys.version)
# Out:
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %%
# need 1.7.x
import torch
print(torch.__version__)
# Out:
# 1.7.1+cu110

# %%
# !nvidia-smi # look for CUDA Version > 11
# Out:
# Fri Nov 12 23:06:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ### Clone Repository

# %%
# !git clone https://github.com/genforce/insgen.git

# %% [markdown]
# ### Prepare Dataset

# %%
#!python3 insgen/dataset_tool.py --source raw_dataset/ --dest processed_dataset/ \
                                --width 64 --height 64
# Out:
# 100% 6/6 [00:01<00:00,  5.52it/s]

# %% [markdown]
# ### Train Model

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# just stylegan (no aug, no insgen) for baseline!
# !python /content/drive/MyDrive/CS236/CS236\ Final\ Project/insgen/train.py \
        --gpus=1 \
        --data=/content/drive/MyDrive/CS236/CS236\ Final\ Project/midi_images \
        --cfg=auto \
        --outdir=/content/drive/MyDrive/CS236/CS236\ Final\ Project/training_examples \
        --no_insgen True \
        --kimg 1000 \
        --snap 5 \
        --aug=noaug
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 5,
#   "network_snapshot_ticks": 5,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/CS236/CS236 Final Project/midi_images",
#     "use_labels": false,
#     "max_size": 4040,
#     "xflip": false,
#     "resolution": 64
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
# ...

# %%
# Things to consider:
# - augmentation of images (choose augmentation methods carefully) -- maybe just noise
# -

# %%
! ls

# %%
# %tensorboard --logdir logs/fit
