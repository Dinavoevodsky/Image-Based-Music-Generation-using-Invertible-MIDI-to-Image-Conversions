# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/CS236/CS236_final_project'
# Out:
# /content/drive/.shortcut-targets-by-id/1fpmTugJ2CE_Z0eo17drgat-VPIRJejGe/CS236_final_project

# %%
import torch
import torchvision

# %%
# %cp -R /content/drive/MyDrive/CS236/CS236_final_project/giant_midi_out/midi_images_highres \
      /content/drive/MyDrive/midi
# Out:
# cp: cannot access '/content/drive/MyDrive/CS236/CS236_final_project/giant_midi_out/midi_images_highres': Input/output error

# %% [markdown]
# ### Train Model

# %%
# %cd /content/drive/MyDrive/CS236/CS236_final_project/WassersteinGAN
# Out:
# /content/drive/.shortcut-targets-by-id/1fpmTugJ2CE_Z0eo17drgat-VPIRJejGe/CS236_final_project/WassersteinGAN

# %%
# !pip install -r requirements.txt

# %%
# !python3 /content/drive/MyDrive/CS236/CS236_final_project/WassersteinGAN/main.py --dataset=folder --dataroot=/content/drive/MyDrive/midi \
        --nc=1 --cuda --niter 1000 --noBN --lrD 0.0005 --lrG 0.0005
# Out:
# Streaming output truncated to the last 5000 lines.
# [645/1000][260/430][53397] Loss_D: -0.348471 Loss_G: 0.481515 Loss_D_real: -0.416172 Loss_D_fake -0.067700
# [645/1000][265/430][53398] Loss_D: -0.421335 Loss_G: -0.051620 Loss_D_real: 0.024870 Loss_D_fake 0.446205
# [645/1000][270/430][53399] Loss_D: -0.410350 Loss_G: 0.553976 Loss_D_real: -0.438026 Loss_D_fake -0.027676
# [645/1000][275/430][53400] Loss_D: -0.371475 Loss_G: -0.232465 Loss_D_real: 0.102106 Loss_D_fake 0.473581
# [645/1000][280/430][53401] Loss_D: -0.339470 Loss_G: 0.372253 Loss_D_real: -0.319747 Loss_D_fake 0.019723
# [645/1000][285/430][53402] Loss_D: -0.345182 Loss_G: -0.231417 Loss_D_real: 0.106854 Loss_D_fake 0.452036
# [645/1000][290/430][53403] Loss_D: -0.343490 Loss_G: 0.503834 Loss_D_real: -0.428210 Loss_D_fake -0.084720
# [645/1000][295/430][53404] Loss_D: -0.349072 Loss_G: -0.152096 Loss_D_real: 0.151668 Loss_D_fake 0.500740
# ...

# %%
# !python3 main.py --dataset=folder --dataroot=/content/drive/MyDrive/CS236/CS236\ Final\ Project/WGAN_training_images/ \
        --nc=1 --cuda --niter 1000 --noBN --lrD 0.0005 --lrG 0.0005
# Out:
# Namespace(Diters=5, adam=False, batchSize=64, beta1=0.5, clamp_lower=-0.01, clamp_upper=0.01, cuda=True, dataroot='/content/drive/MyDrive/CS236/CS236 Final Project/WGAN_training_images/', dataset='folder', experiment=None, imageSize=64, lrD=0.0005, lrG=0.0005, mlp_D=False, mlp_G=False, n_extra_layers=0, nc=1, ndf=64, netD='', netG='', ngf=64, ngpu=1, niter=1000, noBN=True, nz=100, workers=2)
# Random Seed:  9532
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:317: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# DCGAN_G_nobn(
#   (main): Sequential(
#     (initial:100-512:convt): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (initial:512:relu): ReLU(inplace=True)
#     (pyramid:512-256:convt): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# ...

# %%
import os
len(os.listdir('/content/drive/MyDrive/CS236/CS236_final_project/giant_midi_out/midi_images'))

# %%
# %tensorboard --logdir logs/fit
