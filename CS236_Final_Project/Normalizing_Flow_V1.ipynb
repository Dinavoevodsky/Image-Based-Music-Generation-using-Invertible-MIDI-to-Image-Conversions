# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CS236/CS236\ Final\ Project/
# Out:
# /content/drive/.shortcut-targets-by-id/1fpmTugJ2CE_Z0eo17drgat-VPIRJejGe/CS236 Final Project

# %%
#!git clone https://github.com/matejgrcic/DenseFlow.git
# Out:
# Cloning into 'DenseFlow'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 277 (delta 50), reused 260 (delta 44), pack-reused 0
# Receiving objects: 100% (277/277), 1.16 MiB | 3.79 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Checking out files: 100% (206/206), done.

# %%
# !pip install -r DenseFlow/requirements.txt

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !apt-get install python3.8
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.8 is already the newest version (3.8.12-1+bionic1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
pip install -e DenseFlow/.
# Out:
# Obtaining file:///content/drive/.shortcut-targets-by-id/1fpmTugJ2CE_Z0eo17drgat-VPIRJejGe/CS236%20Final%20Project/DenseFlow
# ...
#   Running setup.py develop for denseflow
# ...

# %%
# edit so that we can load in our data -- train with our data (imagenet64 is most similar)
