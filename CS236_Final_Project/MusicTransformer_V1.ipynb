# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CS236/CS236_final_project/music_transformer

# %%
# %cd /content/drive/MyDrive/CS236/CS236\ Final\ Project/MusicTransformer-tensorflow2.0
# Out:
# /content/drive/.shortcut-targets-by-id/1fpmTugJ2CE_Z0eo17drgat-VPIRJejGe/CS236_final_project/MusicTransformer-tensorflow2.0

# %%
#!git clone https://github.com/jason9693/MusicTransformer-pytorch.git
#!git clone https://github.com/jason9693/midi-neural-processor.git
#%mv midi-neural-processor midi_processor
#https://github.com/jason9693/MusicTransformer-pytorch source link
# !pip install -r requirements.txt
# !pip install progress
# !pip install pretty_midi
# Out:
# ...
#      |████████████████████████████████| 99 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 45.8 MB/s
# ...
#      |████████████████████████████████| 96 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.2 MB/s
# ...
# ERROR: Could not find a version that satisfies the requirement bc-dvc-init==0.3.0 (from versions: none)
# ERROR: No matching distribution found for bc-dvc-init==0.3.0
# ...
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9628 sha256=087aa50625a5d25b42f7c39f0032c5c64b2fc19f8b6ca4cd9008f9cd21e07eab
#   Stored in directory: /root/.cache/pip/wheels/8e/d7/61/498d8e27dc11e9805b01eb3539e2ee344436fc226daeb5fe87
# Successfully built progress
# ...
#      |████████████████████████████████| 5.6 MB 10.1 MB/s
# ...
#      |████████████████████████████████| 51 kB 7.7 MB/s
# ...
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591953 sha256=cb4e7af5bba519fc5f9850e4c34a21da27602d6b55119bf84db85bbf66267ae7
# ...

# %%
from midi_processor.processor import encode_midi
# skipped Fugue 6, 8, 11
# skipped Prelude 13, 14, 15

# %%
# !python3 preprocess.py /content/drive/MyDrive/CS236/CS236_final_project/raw_midi_files \
#                        /content/drive/MyDrive/CS236/CS236_final_project/music_transformer_dataset

# %%
# !python train.py -c config/train.yml -m /content/drive/MyDrive/CS236/CS236_final_project/music_transformer/save

# %%
import os
len(os.listdir("/content/drive/MyDrive/CS236/CS236_final_project/music_transformer_dataset"))
# Out:
# 157

# %%
# !pip install tensorboardX
# !pip install -U PyYAML

# %%
# !git clone https://github.com/jason9693/MusicTransformer-tensorflow2.0.git
# %cd MusicTransformer-tensorflow2.0
# !git clone https://github.com/jason9693/midi-neural-processor.git
# %mv midi-neural-processor midi_processor

# %%
# !python train.py --epochs=150 \
                --save_path=/content/drive/MyDrive/CS236/CS236_final_project/MusicTransformer-tensorflow2.0/save/model/ \
                --max_seq=2048 \
                --pickle_dir=/content/drive/MyDrive/CS236/CS236_final_project/music_transformer_dataset/ \
                --batch_size=2 \
                --l_r=0.001
# Out:
# <class Data has "157" files>
# 2021-12-06 21:04:46.224608: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
#   0% 0/78 [00:00<?, ?it/s]
# ...
# Epoch/Batch: 0/0
# Train >>>> Loss: 6.06356, Accuracy: 0.004638671875
# Eval >>>> Loss: 6.27445, Accuracy: 0.0023193359375
# 100% 78/78 [00:43<00:00,  1.78it/s]
#   0% 0/78 [00:00<?, ?it/s]
# ...
# Epoch/Batch: 1/0
# Train >>>> Loss: 4.99766, Accuracy: 0.04833984375
# Eval >>>> Loss: 5.2039, Accuracy: 0.024169921875
# 100% 78/78 [00:32<00:00,  2.41it/s]
#   0% 0/78 [00:00<?, ?it/s]
# ...
# Epoch/Batch: 2/0
# Train >>>> Loss: 5.06999, Accuracy: 0.000732421875
# Eval >>>> Loss: 4.02528, Accuracy: 0.00537109375
# 100% 78/78 [00:30<00:00,  2.52it/s]
#   0% 0/78 [00:00<?, ?it/s]
# ...
# Epoch/Batch: 3/0
# Train >>>> Loss: 4.80994, Accuracy: 0.121337890625
# Eval >>>> Loss: 5.10294, Accuracy: 0.06787109375
# ...

# %%
# !python train.py --epochs=500 \
                --save_path=/content/drive/MyDrive/CS236/CS236_final_project/MusicTransformer-tensorflow2.0/save/model2/ \
                --max_seq=2048 \
                --pickle_dir=/content/drive/MyDrive/CS236/CS236_final_project/music_transformer_dataset/ \
                --batch_size=2 \
                --l_r=0.001 \
                --load_path=/content/drive/MyDrive/CS236/CS236_final_project/MusicTransformer-tensorflow2.0/save/model/
# Out:
# <class Data has "157" files>
# 2021-12-07 18:39:31.110450: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
#   0% 0/78 [00:00<?, ?it/s]
# ...
# Epoch/Batch: 0/0
# Train >>>> Loss: 4.3612, Accuracy: 0.26904296875
# Eval >>>> Loss: 3.81008, Accuracy: 0.1397705078125
#  96% 75/78 [01:25<00:02,  1.46it/s]
# ...
# Epoch/Batch: 0/75
# Train >>>> Loss: 4.52033, Accuracy: 0.0890415757894516
# Eval >>>> Loss:  5.207, Accuracy: 0.08806903660297394
# 100% 78/78 [01:32<00:00,  1.19s/it]
#   0% 0/78 [00:00<?, ?it/s]
# ...
# Epoch/Batch: 1/0
# Train >>>> Loss: 4.86288, Accuracy: 0.137451171875
# Eval >>>> Loss: 5.19536, Accuracy: 0.074462890625
#  96% 75/78 [00:56<00:02,  1.48it/s]
# ...
# Epoch/Batch: 1/75
# Train >>>> Loss: 4.94216, Accuracy: 0.10100129246711731
# Eval >>>> Loss: 3.89037, Accuracy: 0.09983473271131516
# 100% 78/78 [01:03<00:00,  1.23it/s]
# ...

# %%
import os
os.isdir("/content/drive/MyDrive/CS236/CS236_final_project/MusicTransformer-tensorflow2.0/save/generated/")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-faf91ead78ee> in <module>()
#       1 import os
# ----> 2 os.isdir("/content/drive/MyDrive/CS236/CS236_final_project/MusicTransformer-tensorflow2.0/save/generated/")
#
# AttributeError: module 'os' has no attribute 'isdir'

# %%
# !python generate.py --load_path=/content/drive/MyDrive/CS236/CS236\ Final\ Project/MusicTransformer-tensorflow2.0/save/model2/ --length=1000 \
                    --save_path=/content/drive/MyDrive/CS236/CS236\ Final\ Project/MusicTransformer-tensorflow2.0/save/generated/generated2.mid \
# Out:
# 2021-12-07 23:06:31.628191: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# >> generate with decoder wise... beam size is None
# generating |################################| 1000/1000
# 343
# 372
# 56
# 299
# 184
# 372
# 63
# 299
# 191
# 372
# 64
# 55
# 77
# 372
# 190
# 202
# 364
# 48
# 51
# 197
# 256
# 288
# 278
# 381
# 192
# 366
# 372
# 372
# 365
# 372
# 366
# 267
# 180
# 265
# 203
# 78
# 372
# 186
# 69
# 261
# 204
# 270
# 193
# 191
# 74
# 364
# 189
# 180
# 50
# 368
# 381
# 372
# 278
# 372
# 355
# 63
# 278
# 178
# 59
# 372
# 202
# 190
# 189
# 85
# 372
# 176
# 381
# 53
# 167
# 367
# 188
# 65
# 52
# 46
# 176
# 189
# 52
# 263
# 371
# 372
# 57
# 194
# 372
# 381
# 270
# 58
# 381
# 381
# 374
# 67
# 178
# 166
# 76
# 381
# 276
# 60
# 50
# 381
# 270
# 372
# 181
# 372
# 73
# 67
# 369
# 292
# 180
# 57
# 70
# 58
# 188
# 378
# 64
# 185
# 263
# 372
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 99 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 20.1 MB/s
# ...
#      |████████████████████████████████| 96 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.1 MB/s
# ...
# ERROR: Could not find a version that satisfies the requirement bc-dvc-init==0.3.0 (from versions: none)
# ERROR: No matching distribution found for bc-dvc-init==0.3.0

# %% [markdown]
# head size : 4
# number of layers : 6
# seqence length : 2048
# embedding dim : 256 (dh = 256 / 4 = 64)
# batch size : 2
